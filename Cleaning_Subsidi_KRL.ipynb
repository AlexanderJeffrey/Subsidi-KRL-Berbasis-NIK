# %%
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8465c328-dc59-4f21-81c6-c7988630f4c8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8465c328-dc59-4f21-81c6-c7988630f4c8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
file = "subsidiKRL.csv"
df = pd.read_csv(file)

# %%
df.head()
# Out:
#                              date  likes  \
# 0  Mon Sep 30 12:24:19 +0000 2024      0
# 1  Mon Sep 30 11:31:00 +0000 2024      2
# 2  Sun Sep 29 15:26:36 +0000 2024      0
# 3  Sun Sep 29 12:50:51 +0000 2024      0
# 4  Sun Sep 29 12:33:14 +0000 2024     25
#
#                                                 text    label
# 0  Apa cuma gw yang ngerasa krl makin padet? Prad...   netral
# 1  Wacana penerapan subsidi tarif KRL berdasarkan...   netral
# 2  Subsidi KRL Dipersempit Berdasarkan NIK Warga ...  negatif
# 3  @kumparan Saya yakin sih tidak akan seperti an...   netral
# 4  Kementerian BUMN mau diubah jadi Badan pengama...   netral

# %%
df.shape
# Out:
# (1055, 4)

# %%
df = df.drop_duplicates(subset=['text'])

# %%
def clean_twitter_text(text):
    text = re.sub(r'@[A-Za-z0-9_]+', '', text)  # Menghapus mention
    text = re.sub(r'#\w+', '', text) # Menghapus Hashtag
    text = re.sub(r'https?://\S+', '', text) # Menghapus URL
    text = re.sub(r'[0-9]', '', text) # Menghapus Numerik
    text = re.sub(r'[^A-Za-z0-9 ]+', '', text) # Menghapus Karakter non-alfanumerik
    text = re.sub(r'\s+', ' ', text).strip() # Menghapus Spasi Berlebihan
    text = re.sub(r'[\/|\\\?\+\-]', '', text)

    return text

df['text'] = df['text'].apply(clean_twitter_text)

# %%
df
# Out:
#                                 date  likes  \
# 0     Mon Sep 30 12:24:19 +0000 2024      0
# 1     Mon Sep 30 11:31:00 +0000 2024      2
# 2     Sun Sep 29 15:26:36 +0000 2024      0
# 3     Sun Sep 29 12:50:51 +0000 2024      0
# 4     Sun Sep 29 12:33:14 +0000 2024     25
# ...                              ...    ...
# 1050  Wed Aug 28 10:36:47 +0000 2024     16
# 1051  Wed Aug 28 10:30:22 +0000 2024      2
# 1052  Wed Aug 28 10:21:44 +0000 2024      0
# 1053  Wed Aug 28 10:16:00 +0000 2024   2656
# 1054  Wed Aug 28 07:53:15 +0000 2024     22
#
#                                                    text    label
# 0     Apa cuma gw yang ngerasa krl makin padet Pradu...   netral
# 1     Wacana penerapan subsidi tarif KRL berdasarkan...   netral
# 2     Subsidi KRL Dipersempit Berdasarkan NIK Warga ...  negatif
# 3     Saya yakin sih tidak akan seperti analisi pak ...   netral
# 4     Kementerian BUMN mau diubah jadi Badan pengama...   netral
# ...

# %%
# Simpan dataframe yang telah dibersihkan sebagai file csv dengan nama "subsidiKRL_Bersih.csv"
file = "subsidiKRL_Bersih.csv"
df.to_csv(file, index = False)

# %%
from google.colab import files

files.download("subsidiKRL_Bersih.csv")
